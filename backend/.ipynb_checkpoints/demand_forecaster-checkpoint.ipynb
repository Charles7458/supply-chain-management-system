# %%
#Aiming for forecasting demand per (product_id, warehouse_id)
import numpy as np
import pandas as pd
from datetime import date, datetime

products = pd.read_csv("products.csv")
inventory = pd.read_csv("inventory.csv")
sales = pd.read_csv("sales_history.csv")
warehouses = pd.read_csv("warehouses.csv")

# %%
print(products.columns)
print(inventory.columns)
print(sales.columns)
print(warehouses.columns)
# Out:
# Index(['product_id', 'sku', 'product_name', 'category', 'unit_price',
#        'created_at'],
#       dtype='object')
# Index(['inventory_id', 'product_id', 'warehouse_id', 'stock_level',
#        'last_updated'],
#       dtype='object')
# Index(['sale_id', 'product_id', 'warehouse_id', 'sale_date', 'quantity_sold',
#        'revenue'],
#       dtype='object')
# Index(['warehouse_id', 'warehouse_name', 'city', 'state', 'zip_code',
#        'capacity'],
#       dtype='object')

# %%
#Product table cleaning

#Removing products with duplicate IDs
products.drop_duplicates(subset=['product_id'])

#Fix category formatting
products['category'] = (
    products['category']
        .astype(str)
    .str.lower()
    .str.strip())

#Converting to datetime
products['created_at'] = pd.to_datetime(products['created_at'])

#Removing products with negative or zero unit_price
products = products[products['unit_price'] >= 0]

print(products.head(5))
# Out:
#    product_id      sku        product_name            category  unit_price  \
# 0           1  HC-0003   Laundry Detergent  household cleaning        4.94
# 1           2  SN-0029  Rice Crackers 10oz              snacks        7.05
# 2           3  PC-0012           Hand Soap       personal care       14.67
# 3           4  PS-0037  Peanut Butter 16oz      pantry staples       15.31
# 4           5  HC-0007     Bleach Solution  household cleaning        7.75
#
#   created_at
# 0 2024-01-03
# 1 2024-01-08
# 2 2024-01-18
# 3 2024-01-18
# 4 2024-01-22

# %%
#cleaning inventory table
#converting to datetime
inventory['last_updated'] = pd.to_datetime(inventory['last_updated'])
#Removing entries with negative stock_level
inventory = inventory[ inventory['stock_level'] > 0 ]

# %%
#sales history table cleaning
#Drop duplicate rows
sales.drop_duplicates(subset=['sale_id'])
#Removing invalid rows
sales = sales[ (sales['quantity_sold'] > 0) & (sales['revenue'] > 0) ]
#converting to datetime
sales['sale_date'] = pd.to_datetime(sales['sale_date'])
#Aggregate into daily demand
sales_daily = (
    sales
    .groupby(['product_id','warehouse_id','sale_date'])
    ['quantity_sold']
    .sum()
    .reset_index()
)

sales_daily= sales_daily.rename(
    columns = {'quantity_sold':'demand'}
)

# %%
#Warehouse table cleaning
#Normalize city and state
warehouses['city'] = warehouses['city'].str.title().str.strip()
warehouses['state'] = warehouses['state'].str.title().str.strip()

#Filling missing capacity
warehouses['capacity'] = (
    warehouses['capacity']
    .fillna(warehouses['capacity'].median())
)

# %%
print(inventory.head(10))
# Out:
#    inventory_id  product_id  warehouse_id  stock_level last_updated
# 0           184          31             7           85   2024-03-10
# 1            73          13             4          428   2024-03-10
# 2            92          16            10          330   2024-03-10
# 3            99          17             7           83   2024-03-10
# 4           117          20             4          284   2024-03-10
# 5           119          20             3          409   2024-03-10
# 6           125          21             5          122   2024-03-10
# 7           127          21             6           39   2024-03-10
# 8           216          36             4          233   2024-03-10
# 9           218          36             6           93   2024-03-10

# %%
#Create Master Dataset 
#creating master table by adding sales_daily joined with corresponding products and warehouses

master = (
    sales_daily
    .merge(products, on='product_id', how='left')
    .merge(warehouses, on='warehouse_id', how='left')
)

# %%
# master = master.merge(
#     inventory[['product_id','warehouse_id','date','stock_level']],
#     left_on=['product_id','warehouse_id','sale_date'],
#     right_on=['product_id','warehouse_id','date'],
#     how='left'
# )
master = master.sort_values('sale_date')
inventory = inventory.sort_values('last_updated')

master = pd.merge_asof(
    master,
    inventory[['product_id', 'warehouse_id','stock_level','last_updated']],
    left_on='sale_date',
    right_on='last_updated',
    by=['product_id','warehouse_id'],
    direction='backward'
)

print(master.head(5))
# Out:
#    product_id  warehouse_id  sale_date  demand      sku        product_name  \
# 0           2             2 2024-06-10      17  SN-0029  Rice Crackers 10oz
# 1           7             3 2024-06-10       7  PD-0045     Trash Bags 50ct
# 2          39             7 2024-06-10      19  PD-0050      Wax Paper 75ft
# 3          28             2 2024-06-10       4  HC-0006  Disinfectant Spray
# 4          35             1 2024-06-10       9  BV-0022    Apple Cider 32oz
#
#                 category  unit_price created_at  \
# 0                 snacks        7.05 2024-01-08
# 1  paper and disposables       10.22 2024-01-27
# 2  paper and disposables       11.81 2024-05-12
# 3     household cleaning        9.50 2024-04-11
# 4              beverages       19.68 2024-05-03
#
#                    warehouse_name      city state  zip_code  capacity  \
# 0       Southeast Fulfillment Hub   Atlanta    Ga     30301     45000
# 1        Midwest Logistics Center  Columbus    Oh     43004     40000
# 2        Pacific Northwest Center  Portland    Or     97201     38000
# 3       Southeast Fulfillment Hub   Atlanta    Ga     30301     45000
# 4  East Coast Distribution Center    Edison    Nj      8817     50000
#
#    stock_level last_updated
# 0        290.0   2024-03-11
# 1        279.0   2024-03-15
# 2          NaN          NaT
# 3        129.0   2024-03-13
# 4        112.0   2024-03-12

# %%
# master['stock_level'] = (
#     master.groupby(['product_id','warehouse_id'])['stock_level']
#     .transform(lambda x: x.fillna(x.mean()))
# )

master['stock_level'] = (
    master.groupby(['product_id','warehouse_id'])['stock_level']
    .ffill()
)

master['last_updated'] = (
    master.groupby(['product_id','warehouse_id'])['last_updated']
    .ffill()
)

master['stock_level'] = master['stock_level'].fillna(
    master['stock_level'].mean()
)

# %%
print(master[np.isnan(master['stock_level'])])
# Out:
# Empty DataFrame
# Columns: [product_id, warehouse_id, sale_date, demand, sku, product_name, category, unit_price, created_at, warehouse_name, city, state, zip_code, capacity, stock_level, last_updated]
# Index: []

# %%
print(master[master['last_updated']==np.datetime64('NaT') ])
# Out:
# Empty DataFrame
# Columns: [product_id, warehouse_id, sale_date, demand, sku, product_name, category, unit_price, created_at, warehouse_name, city, state, zip_code, capacity, stock_level, last_updated]
# Index: []

# %%
def make_continuous(df):

    idx = pd.date_range(
        df['sale_date'].min(),
        df['sale_date'].max()
    )

    df = (
        df.set_index('sale_date')
          .reindex(idx)
          .rename_axis('sale_date')
          .reset_index()
    )

    df['demand'] = df['demand'].fillna(0)

    return df

# %%
#Filling empty stock_level entries with forward fill
master = (
    master
    .set_index('sale_date')
    .groupby(['product_id','warehouse_id'])
    .resample('D')
    .agg({
        'demand':'sum',
        'stock_level':'last'
    })
    .reset_index()
)

master['demand'] = master['demand'].fillna(0)

master['stock_level'] = (
    master.groupby(['product_id','warehouse_id'])['stock_level']
    .ffill()
)

# %%
#converting stock_levels to integer for realism
master['stock_level'] = master['stock_level'].round().astype(int)

# %%
master['stock_change'] = master.groupby(
    ['product_id','warehouse_id']
)['stock_level'].diff()

# %%
master['stockout_flag'] = (master['stock_level'] <= master['demand']).astype(int)

# %%
master['day_of_week'] = master['sale_date'].dt.dayofweek
master['month'] = master['sale_date'].dt.month
master['is_weekend'] = master['day_of_week'].isin([5,6]).astype(int)

# %%
#Improving demand density for better signals
baseline = np.random.poisson(2, size=len(master))
noise = np.random.randint(0,3,len(master))

master['demand'] = baseline + noise

# %%
#Adding Seasonality
dow = master['sale_date'].dt.dayofweek

master.loc[dow >= 5, 'demand'] += np.random.randint(2,5)

# %%
#Adding Stockout Logic
master.loc[master['stock_level'] == 0, 'demand'] = 0

# %%
master = master.sort_values(
    ['product_id','warehouse_id','sale_date']
)

master['lag_1'] = (
    master.groupby(['product_id','warehouse_id'])['demand']
    .shift(1)
)

master['lag_7'] = (
    master.groupby(['product_id','warehouse_id'])['demand']
    .shift(7)
)

master['rolling_mean_7'] = (
    master.groupby(['product_id','warehouse_id'])['demand']
    .transform(lambda x: x.shift(1).rolling(7).mean())
)

# %%
master['stockout_flag'] = (
    master['stock_level'] == 0
).astype(int)

master.dropna()
# Out:
#         product_id  warehouse_id  sale_date  demand  stock_level  \
# 7                1             1 2024-06-22       5          107
# 8                1             1 2024-06-23       8          107
# 9                1             1 2024-06-24       5          107
# 10               1             1 2024-06-25       4          107
# 11               1             1 2024-06-26       4          107
# ...            ...           ...        ...     ...          ...
# 146529          50            10 2025-04-22       5           92
# 146530          50            10 2025-04-23       2           92
# 146531          50            10 2025-04-24       4           92
# 146532          50            10 2025-04-25       5           92
# 146533          50            10 2025-04-26       7           92
#
#         stock_change  stockout_flag  day_of_week  month  is_weekend  lag_1  \
# 7                0.0              0            5      6           1    3.0
# 8                0.0              0            6      6           1    5.0
# 9                0.0              0            0      6           0    8.0
# 10               0.0              0            1      6           0    5.0
# 11               0.0              0            2      6           0    4.0
# ...              ...            ...          ...    ...         ...    ...
# 146529           0.0              0            1      4           0    2.0
# 146530           0.0              0            2      4           0    5.0
# 146531           0.0              0            3      4           0    2.0
# 146532           0.0              0            4      4           0    4.0
# 146533           0.0              0            5      4           1    5.0
#
#         lag_7  rolling_mean_7
# 7         2.0        3.857143
# 8         8.0        4.285714
# 9         4.0        4.285714
# 10        3.0        4.428571
# 11        4.0        4.571429
# ...       ...             ...
# 146529    3.0        3.714286
# 146530    2.0        4.000000
# 146531    6.0        4.000000
# 146532    3.0        3.714286
# 146533    4.0        4.000000
#
# [143034 rows x 13 columns]

# %%
print(master.head(10))
print (master.tail(10))
# Out:
#    product_id  warehouse_id  sale_date  demand  stock_level  stock_change  \
# 0           1             1 2024-06-15       2          107           NaN
# 1           1             1 2024-06-16       8          107           0.0
# 2           1             1 2024-06-17       4          107           0.0
# 3           1             1 2024-06-18       3          107           0.0
# 4           1             1 2024-06-19       4          107           0.0
# 5           1             1 2024-06-20       3          107           0.0
# 6           1             1 2024-06-21       3          107           0.0
# 7           1             1 2024-06-22       5          107           0.0
# 8           1             1 2024-06-23       8          107           0.0
# 9           1             1 2024-06-24       5          107           0.0
#
#    stockout_flag  day_of_week  month  is_weekend  lag_1  lag_7  rolling_mean_7
# 0              0            5      6           1    NaN    NaN             NaN
# 1              0            6      6           1    2.0    NaN             NaN
# 2              0            0      6           0    8.0    NaN             NaN
# 3              0            1      6           0    4.0    NaN             NaN
# 4              0            2      6           0    3.0    NaN             NaN
# 5              0            3      6           0    4.0    NaN             NaN
# 6              0            4      6           0    3.0    NaN             NaN
# 7              0            5      6           1    3.0    2.0        3.857143
# 8              0            6      6           1    5.0    8.0        4.285714
# 9              0            0      6           0    8.0    4.0        4.285714
#         product_id  warehouse_id  sale_date  demand  stock_level  \
# 146524          50            10 2025-04-17       6           92
# 146525          50            10 2025-04-18       3           92
# 146526          50            10 2025-04-19       4           92
# 146527          50            10 2025-04-20       6           92
# 146528          50            10 2025-04-21       2           92
# 146529          50            10 2025-04-22       5           92
# 146530          50            10 2025-04-23       2           92
# 146531          50            10 2025-04-24       4           92
# 146532          50            10 2025-04-25       5           92
# 146533          50            10 2025-04-26       7           92
#
#         stock_change  stockout_flag  day_of_week  month  is_weekend  lag_1  \
# 146524           0.0              0            3      4           0    2.0
# 146525           0.0              0            4      4           0    6.0
# 146526           0.0              0            5      4           1    3.0
# 146527           0.0              0            6      4           1    4.0
# 146528           0.0              0            0      4           0    6.0
# 146529           0.0              0            1      4           0    2.0
# 146530           0.0              0            2      4           0    5.0
# 146531           0.0              0            3      4           0    2.0
# 146532           0.0              0            4      4           0    4.0
# 146533           0.0              0            5      4           1    5.0
#
#         lag_7  rolling_mean_7
# 146524    6.0        4.000000
# 146525    4.0        4.000000
# 146526    5.0        3.857143
# 146527    4.0        3.714286
# 146528    4.0        4.000000
# 146529    3.0        3.714286
# 146530    2.0        4.000000
# 146531    6.0        4.000000
# 146532    3.0        3.714286
# 146533    4.0        4.000000

# %%
print(master[master['lag_1'] == master['lag_1']])
# Out:
#         product_id  warehouse_id  sale_date  demand  stock_level  \
# 1                1             1 2024-06-16       8          107
# 2                1             1 2024-06-17       4          107
# 3                1             1 2024-06-18       3          107
# 4                1             1 2024-06-19       4          107
# 5                1             1 2024-06-20       3          107
# ...            ...           ...        ...     ...          ...
# 146529          50            10 2025-04-22       5           92
# 146530          50            10 2025-04-23       2           92
# 146531          50            10 2025-04-24       4           92
# 146532          50            10 2025-04-25       5           92
# 146533          50            10 2025-04-26       7           92
#
#         stock_change  stockout_flag  day_of_week  month  is_weekend  lag_1  \
# 1                0.0              0            6      6           1    2.0
# 2                0.0              0            0      6           0    8.0
# 3                0.0              0            1      6           0    4.0
# 4                0.0              0            2      6           0    3.0
# 5                0.0              0            3      6           0    4.0
# ...              ...            ...          ...    ...         ...    ...
# 146529           0.0              0            1      4           0    2.0
# 146530           0.0              0            2      4           0    5.0
# 146531           0.0              0            3      4           0    2.0
# 146532           0.0              0            4      4           0    4.0
# 146533           0.0              0            5      4           1    5.0
#
#         lag_7  rolling_mean_7
# 1         NaN             NaN
# 2         NaN             NaN
# 3         NaN             NaN
# 4         NaN             NaN
# 5         NaN             NaN
# ...       ...             ...
# 146529    3.0        3.714286
# 146530    2.0        4.000000
# 146531    6.0        4.000000
# 146532    3.0        3.714286
# 146533    4.0        4.000000
#
# [146034 rows x 13 columns]

# %%
print(master['demand'].describe())
print(master['demand'].value_counts(normalize=True).head())
# Out:
# count    146534.000000
# mean          3.578698
# std           1.868738
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max          13.000000
# Name: demand, dtype: float64
# demand
# 3    0.210258
# 4    0.194194
# 2    0.172527
# 5    0.141578
# 1    0.097138
# Name: proportion, dtype: float64

# %%
master.groupby(
    ['product_id','warehouse_id']
)['sale_date'].diff().value_counts().head()
# Out:
# sale_date
# 1 days    146034
# Name: count, dtype: int64

# %%
print(master[master['stock_level'] - master['stock_level'].astype(int) > 0])
# Out:
# Empty DataFrame
# Columns: [product_id, warehouse_id, sale_date, demand, stock_level, stock_change, stockout_flag, day_of_week, month, is_weekend, lag_1, lag_7, rolling_mean_7]
# Index: []

# %%
#Final data cleaning before training model
master = master.sort_values(
    ['product_id','warehouse_id','sale_date']
)

master = master.dropna().reset_index(drop=True)

# %%
FEATURES = [
    'lag_1',
    'lag_7',
    'rolling_mean_7',
    'day_of_week',
    'month',
    'is_weekend',
    'stock_level',
    'stock_change',
    'stockout_flag'
]

TARGET = 'demand'

# %%
split_date = master['sale_date'].max() - pd.Timedelta(days=30)

train = master[master['sale_date'] <= split_date].copy()
test  = master[master['sale_date'] >  split_date].copy()

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=200,
    max_depth=12,
    min_samples_leaf=5,
    random_state=42,
    n_jobs=-1
)

model.fit(train[FEATURES], train[TARGET])
# Out:
# RandomForestRegressor(max_depth=12, min_samples_leaf=5, n_estimators=200,
#                       n_jobs=-1, random_state=42)

# %%
test['pred_demand'] = model.predict(test[FEATURES])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae  = mean_absolute_error(test[TARGET], test['pred_demand'])
rmse = np.sqrt(mean_squared_error(test[TARGET], test['pred_demand']))

mape = np.mean(
    np.abs(
        (test[TARGET] - test['pred_demand']) /
        np.clip(test[TARGET],1,None)
    )
) * 100

print("MAE :", mae)
print("RMSE:", rmse)
print("MAPE:", mape)
# Out:
# MAE : 1.270123018530853
# RMSE: 1.630604637052368
# MAPE: 54.28446355480939

# %%
future_days = 7

forecast_rows = []

last_data = master.copy()

for step in range(1, future_days + 1):

    next_date = last_data['sale_date'].max() + pd.Timedelta(days=1)

    future_df = (
        last_data
        .sort_values(['product_id','warehouse_id','sale_date'])
        .groupby(['product_id','warehouse_id'])
        .tail(1)
        .copy()
    )

    future_df['sale_date'] = next_date

    future_df['lag_7'] = future_df['lag_1']
    future_df['lag_1'] = future_df['demand']

    future_df['rolling_mean_7'] = (
        future_df[['lag_1','lag_7']].mean(axis=1)
    )

    future_df['day_of_week'] = future_df['sale_date'].dt.dayofweek
    future_df['month'] = future_df['sale_date'].dt.month
    future_df['is_weekend'] = future_df['day_of_week'].isin([5,6]).astype(int)

    future_df['pred_demand'] = model.predict(
        future_df[FEATURES]
    )

    future_df['demand'] = future_df['pred_demand']

    forecast_rows.append(future_df)

    last_data = pd.concat([last_data, future_df])

# %%
forecast_df = pd.concat(forecast_rows)

forecast_df = forecast_df[[
    'product_id',
    'warehouse_id',
    'sale_date',
    'pred_demand'
]]

# %%
history = master[
    (master['product_id']==pid) &
    (master['warehouse_id']==wid)
].sort_values('sale_date')

plt.figure(figsize=(16,6))

plt.plot(
    history['sale_date'],
    history['demand'],
    label='Historical Demand'
)

plt.plot(
    forecast_df['sale_date'],
    forecast_df['pred_demand'],
    label='Future RF Forecast',
    linewidth=3
)

plt.title("Historical + Future Forecast")
plt.legend()
plt.grid()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 history = master[
# ----> 2     (master['product_id']==pid) &
#       3     (master['warehouse_id']==wid)
#       4 ].sort_values('sale_date')
#       6 plt.figure(figsize=(16,6))
#       8 plt.plot(
#       9     history['sale_date'],
#      10     history['demand'],
#      11     label='Historical Demand'
#      12 )
#
# NameError: name 'pid' is not defined
